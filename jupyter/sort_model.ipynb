# %% [markdown]
# # 排序模型
#
# 通过召回的操作，我们已经进行了问题规模的缩减，对于每个用户，选择出了 N 篇文章作为了候选集，并基于召回的候选集构建了与用户历史相关的特征，以及用户本身的属性特征，文章本身的属性特征，以及用户与文章之间的特征。
#
# 下面就是使用机器学习模型来对构造好的特征进行学习，然后对测试集进行预测，得到测试集中的每个候选集用户点击的概率，返回点击概率最大的 topk 个文章，作为最终的结果。
#
# 排序阶段选择了三个比较有代表性的排序模型，它们分别是：
#
# 1. LGB 的排序模型
# 2. LGB 的分类模型
# 3. 深度学习的分类模型 DIN
#
# 得到了最终的排序模型输出的结果之后，还选择了两种比较经典的模型集成的方法：
#
# 1. 输出结果加权融合
# 2. Staking（将模型的输出结果再使用一个简单模型进行预测）

# %%
import pickle
import numpy as np
import pandas as pd
from tqdm import tqdm
import lightgbm as lgb
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 读取排序特征

# %%
data_path = './data/'
feature_path = './tmp_results/feature/'
rank_path = './tmp_results/rank/'
offline = False

# %%
# 重新读取数据的时候，发现 click_article_id 是一个浮点数，所以将其转换成int类型
trn_user_item_feats_df = pd.read_csv(feature_path + 'trn_user_item_feats_df.csv')
trn_user_item_feats_df['click_article_id'] = trn_user_item_feats_df['click_article_id'].astype(int)

if offline:
    val_user_item_feats_df = pd.read_csv(feature_path + 'val_user_item_feats_df.csv')
    val_user_item_feats_df['click_article_id'] = val_user_item_feats_df['click_article_id'].astype(int)
else:
    val_user_item_feats_df = None

tst_user_item_feats_df = pd.read_csv(feature_path + 'tst_user_item_feats_df.csv')
tst_user_item_feats_df['click_article_id'] = tst_user_item_feats_df['click_article_id'].astype(int)

# # 做特征的时候为了方便，给测试集也打上了一个无效的标签，这里直接删掉就行
del tst_user_item_feats_df['label']

# %% [markdown]
# ---
#
# ## 2 返回排序后的结果

# %%
def submit(recall_df: pd.DataFrame, topk: int = 5, model_name: str = None) -> None:
    """
    提交推荐结果，生成提交格式的 DataFrame 并保存为 CSV 文件。

    Args:
        recall_df (`pd.DataFrame`): 包含用户推荐结果的 DataFrame，必须包含 'user_id' 和 'pred_score' 列。
        topk (`int`, optional): 每个用户推荐的文章数量，默认为 5。
        model_name (`str`, optional): 模型名称，用于保存文件时的命名。

    Returns:
        `None`: 该函数没有返回值，但会将结果保存为 CSV 文件。
    """
    # 根据用户 ID 和预测分数排序
    recall_df = recall_df.sort_values(by=['user_id', 'pred_score'], ascending=[True, False])
    
    # 为每个用户的推荐结果打排名
    recall_df['rank'] = recall_df.groupby(['user_id'])['pred_score'].rank(ascending=False, method='first')
    
    # 检查每个用户至少有 topk 篇文章
    tmp = recall_df.groupby('user_id').apply(lambda x: x['rank'].max())
    # assert tmp.min() >= topk, f"Some users do not have at least {topk} articles."
    
    # 删除预测分数列
    del recall_df['pred_score']
    
    # 选择排名在 topk 以内的文章并调整 DataFrame 格式
    submit = recall_df[recall_df['rank'] <= topk].set_index(['user_id', 'rank']).unstack(-1).reset_index()
    
    # 转换列名，去掉多层索引
    submit.columns = [int(col) if isinstance(col, int) else col for col in submit.columns.droplevel(0)]
    
    # 按照提交格式定义列名
    submit = submit.rename(columns={'': 'user_id', 1: 'article_1', 2: 'article_2', 
                                     3: 'article_3', 4: 'article_4', 5: 'article_5'})

    # 保存结果为 CSV 文件
    save_name = rank_path + model_name + '_' + datetime.today().strftime('%m-%d') + '.csv'
    submit.to_csv(save_name, index=False, header=True)  # 保存不包含索引，包含标题

# %%
def norm_sim(sim_df: pd.Series, weight: float = 0.0) -> pd.Series:
    """
    对相似度得分进行归一化处理。

    Args:
        sim_df (`pd.Series`): 输入的相似度得分 Series。
        weight (`float`, optional): 归一化后加上的权重，默认为 0.0。

    Returns:
        `pd.Series`: 归一化后的相似度得分 Series。
    """
    
    # 获取相似度得分的最小值和最大值
    min_sim = sim_df.min()
    max_sim = sim_df.max()
    
    # 如果最大值等于最小值，则所有得分都设置为 1.0
    if max_sim == min_sim:
        sim_df = sim_df.apply(lambda sim: 1.0)
    else:
        # 否则进行线性归一化处理
        sim_df = sim_df.apply(lambda sim: 1.0 * (sim - min_sim) / (max_sim - min_sim))

    # 将指定的权重加到归一化后的相似度得分上
    sim_df = sim_df.apply(lambda sim: sim + weight)  # 加上权重

    return sim_df  # 返回归一化后的相似度得分

# %% [markdown]
# ---
#
# ## 3 LGB 排序模型

# %%
# 防止中间出错之后重新读取数据
trn_user_item_feats_df_rank_model = trn_user_item_feats_df.copy()

if offline:
    val_user_item_feats_df_rank_model = val_user_item_feats_df.copy()
    
tst_user_item_feats_df_rank_model = tst_user_item_feats_df.copy()

# %%
trn_user_item_feats_df_rank_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48383 entries, 0 to 48382
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              48383 non-null  int64
#  1   click_article_id     48383 non-null  int64
#  2   sim0                 5291 non-null   float64
#  3   time_diff0           5291 non-null   float64
#  4   word_diff0           5291 non-null   float64
#  5   sim_max              5291 non-null   float64
#  6   sim_min              5291 non-null   float64
#  7   sim_sum              48383 non-null  float64
#  8   sim_mean             5291 non-null   float64
#  9   score                35983 non-null  float64
#  10  rank                 48383 non-null  int64
#  11  label                48383 non-null  float64
#  12  click_size           48383 non-null  float64
#  13  time_diff_mean       48383 non-null  float64
#  14  active_level         48383 non-null  float64
#  15  click_environment    48383 non-null  int64
#  16  click_deviceGroup    48383 non-null  int64
#  17  click_os             48383 non-null  int64
#  18  click_country        48383 non-null  int64
#  19  click_region         48383 non-null  int64
#  20  click_referrer_type  48383 non-null  int64
#  21  user_time_hob1       48383 non-null  float64
#  22  user_time_hob2       48383 non-null  float64
#  23  words_hbo            48383 non-null  float64
#  24  category_id          48383 non-null  int64
#  25  created_at_ts        48383 non-null  int64
#  26  words_count          48383 non-null  int64
#  27  is_cat_hab           48383 non-null  int64
# dtypes: float64(15), int64(13)
# memory usage: 10.3 MB

# %%
# 定义特征列
lgb_cols = ['sim0', 'time_diff0', 'word_diff0','sim_max', 'sim_min', 'sim_sum', 
            'sim_mean', 'score','click_size', 'time_diff_mean', 'active_level',
            'click_environment','click_deviceGroup', 'click_os', 'click_country', 
            'click_region','click_referrer_type', 'user_time_hob1', 'user_time_hob2',
            'words_hbo', 'category_id', 'created_at_ts','words_count']

# %%
# 排序模型分组
trn_user_item_feats_df_rank_model.sort_values(by=['user_id'], inplace=True)
g_train = trn_user_item_feats_df_rank_model.groupby(['user_id'], as_index=False).count()["label"].values

if offline:
    val_user_item_feats_df_rank_model.sort_values(by=['user_id'], inplace=True)
    g_val = val_user_item_feats_df_rank_model.groupby(['user_id'], as_index=False).count()["label"].values

# %%
# 排序模型定义
lgb_ranker = lgb.LGBMRanker(boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=1,
                            max_depth=-1, n_estimators=100, subsample=0.7, colsample_bytree=0.7, subsample_freq=1,
                            learning_rate=0.01, min_child_weight=50, random_state=2018, n_jobs= 16)

# %%
trn_user_item_feats_df
# Out:
#        user_id  click_article_id      sim0    time_diff0  word_diff0  \
# 0            0              3244       NaN           NaN         NaN
# 1            5              8603       NaN           NaN         NaN
# 2            6              8017       NaN           NaN         NaN
# 3            6             10243       NaN           NaN         NaN
# 4           18              8609       NaN           NaN         NaN
# ...        ...               ...       ...           ...         ...
# 48378   199958              8609       NaN           NaN         NaN
# 48379   199961              1330       NaN           NaN         NaN
# 48380   199975               598  0.449289  8.110598e+10        55.0
# 48381   199988              8710       NaN           NaN         NaN
# 48382   199997              8603       NaN           NaN         NaN
#
#         sim_max   sim_min   sim_sum  sim_mean     score  ...  click_country  \
# 0           NaN       NaN  0.000000       NaN  0.375211  ...              1
# 1           NaN       NaN  0.000000       NaN       NaN  ...              1
# 2           NaN       NaN  0.000000       NaN  0.078042  ...              1
# 3           NaN       NaN  0.000000       NaN  0.173251  ...              1
# 4           NaN       NaN  0.000000       NaN  0.000000  ...              1
# ...         ...       ...       ...       ...       ...  ...            ...
# 48378       NaN       NaN  0.000000       NaN  0.000000  ...              1
# 48379       NaN       NaN  0.000000       NaN  0.000000  ...              1
# 48380  0.449289  0.449289  0.449289  0.449289  0.000000  ...              1
# 48381       NaN       NaN  0.000000       NaN       NaN  ...              6
# 48382       NaN       NaN  0.000000       NaN       NaN  ...              1
#
#        click_region  click_referrer_type  user_time_hob1  user_time_hob2  \
# 0                25                    2        0.343715        0.992865
# 1                25                    2        0.343598        0.992789
# 2                 2                    1        0.343844        0.991332
# 3                 2                    1        0.343844        0.991332
# 4                13                    2        0.343523        0.992784
# ...             ...                  ...             ...             ...
# 48378            10                    1        0.228723        0.990938
# 48379            20                    1        0.191252        0.991104
# 48380            25                    2        0.178436        0.990914
# 48381            28                    2        0.019358        0.989220
# 48382            16                    1        0.019385        0.989068
#
#         words_hbo  category_id  created_at_ts  words_count  is_cat_hab
# 0      266.000000            1  1508220059000          153           0
# 1      226.000000            6  1491484758000          164           0
# 2      188.500000            6  1515513946000          240           0
# 3      188.500000            6  1507990586000          233           0
# 4      197.500000            6  1506106322000          174           0
# ...           ...          ...            ...          ...         ...
# 48378  220.562500            6  1506106322000          174           0
# 48379  209.250000            1  1471301725000          187           0
# 48380  197.736842            1  1426443309000          143           0
# 48381  251.500000            6  1519057619000          164           0
# 48382  174.500000            6  1491484758000          164           0
#
# [48383 rows x 28 columns]

# %%
# 排序模型训练
if offline:
    lgb_ranker.fit(trn_user_item_feats_df_rank_model[lgb_cols], trn_user_item_feats_df_rank_model['label'], group=g_train,
                eval_set=[(val_user_item_feats_df_rank_model[lgb_cols], val_user_item_feats_df_rank_model['label'])], 
                eval_group= [g_val], eval_at=[1, 2, 3, 4, 5], eval_metric=['ndcg', ], early_stopping_rounds=50, )
else:
    lgb_ranker.fit(trn_user_item_feats_df[lgb_cols], trn_user_item_feats_df['label'], group=g_train)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004886 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3839
# [LightGBM] [Info] Number of data points in the train set: 48383, number of used features: 23
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# 模型预测
tst_user_item_feats_df['pred_score'] = lgb_ranker.predict(tst_user_item_feats_df[lgb_cols], num_iteration=lgb_ranker.best_iteration_)

# 将这里的排序结果保存一份，用户后面的模型融合
tst_user_item_feats_df[['user_id', 'click_article_id', 'pred_score']].to_csv(rank_path + 'lgb_ranker_score.csv', index=False)

# %%
# 预测结果重新排序, 及生成提交结果
rank_results = tst_user_item_feats_df[['user_id', 'click_article_id', 'pred_score']]
rank_results['click_article_id'] = rank_results['click_article_id'].astype(int)
submit(rank_results, topk=5, model_name='lgb_ranker')

# %%
# 五折交叉验证，这里的五折交叉是以用户为目标进行五折划分
#  这一部分与前面的单独训练和验证是分开的
def get_kfold_users(trn_df, n=5):
    user_ids = trn_df['user_id'].unique()
    user_set = [user_ids[i::n] for i in range(n)]
    return user_set

k_fold = 5
trn_df = trn_user_item_feats_df_rank_model
user_set = get_kfold_users(trn_df, n=k_fold)

score_list = []
score_df = trn_df[['user_id', 'click_article_id','label']]
sub_preds = np.zeros(tst_user_item_feats_df_rank_model.shape[0])

# 五折交叉验证，并将中间结果保存用于staking
for n_fold, valid_user in enumerate(user_set):
    train_idx = trn_df[~trn_df['user_id'].isin(valid_user)] # add slide user
    valid_idx = trn_df[trn_df['user_id'].isin(valid_user)]
    
    # 训练集与验证集的用户分组
    train_idx.sort_values(by=['user_id'], inplace=True)
    g_train = train_idx.groupby(['user_id'], as_index=False).count()["label"].values
    
    valid_idx.sort_values(by=['user_id'], inplace=True)
    g_val = valid_idx.groupby(['user_id'], as_index=False).count()["label"].values
    
    # 定义模型
    lgb_ranker = lgb.LGBMRanker(boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=1,
                            max_depth=-1, n_estimators=100, subsample=0.7, colsample_bytree=0.7, subsample_freq=1,
                            learning_rate=0.01, min_child_weight=50, random_state=2018, n_jobs= 16)  
    # 训练模型
    lgb_ranker.fit(train_idx[lgb_cols], train_idx['label'], group=g_train,
                   eval_set=[(valid_idx[lgb_cols], valid_idx['label'])], eval_group= [g_val], 
                   eval_at=[1, 2, 3, 4, 5], eval_metric=['ndcg', ])
    
    # 预测验证集结果
    valid_idx['pred_score'] = lgb_ranker.predict(valid_idx[lgb_cols], num_iteration=lgb_ranker.best_iteration_)
    
    # 对输出结果进行归一化
    valid_idx['pred_score'] = valid_idx[['pred_score']].transform(lambda x: norm_sim(x))
    
    valid_idx.sort_values(by=['user_id', 'pred_score'])
    valid_idx['pred_rank'] = valid_idx.groupby(['user_id'])['pred_score'].rank(ascending=False, method='first')
    
    # 将验证集的预测结果放到一个列表中，后面进行拼接
    score_list.append(valid_idx[['user_id', 'click_article_id', 'pred_score', 'pred_rank']])
    
    # 如果是线上测试，需要计算每次交叉验证的结果相加，最后求平均
    # if not offline:
    #     sub_preds += lgb_ranker.predict(tst_user_item_feats_df_rank_model[lgb_cols], lgb_ranker.best_iteration_)
    
score_df_ = pd.concat(score_list, axis=0)
score_df = score_df.merge(score_df_, how='left', on=['user_id', 'click_article_id'])

# 保存训练集交叉验证产生的新特征
score_df[['user_id', 'click_article_id', 'pred_score', 'pred_rank', 'label']].to_csv(rank_path + 'trn_lgb_ranker_feats.csv', index=False)
    
# 测试集的预测结果，多次交叉验证求平均，将预测的 score 和对应的 rank 特征保存，可以用于后面的 staking，这里还可以构造其他更多的特征
tst_user_item_feats_df_rank_model['pred_score'] = sub_preds / k_fold
tst_user_item_feats_df_rank_model['pred_score'] = tst_user_item_feats_df_rank_model['pred_score'].transform(lambda x: norm_sim(x))
tst_user_item_feats_df_rank_model.sort_values(by=['user_id', 'pred_score'])
tst_user_item_feats_df_rank_model['pred_rank'] = tst_user_item_feats_df_rank_model.groupby(['user_id'])['pred_score'].rank(ascending=False, method='first')

# 保存测试集交叉验证的新特征
tst_user_item_feats_df_rank_model[['user_id', 'click_article_id', 'pred_score', 'pred_rank']].to_csv(rank_path + 'tst_lgb_ranker_feats.csv', index=False)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003976 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3822
# [LightGBM] [Info] Number of data points in the train set: 38772, number of used features: 23
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003359 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3828
# [LightGBM] [Info] Number of data points in the train set: 38738, number of used features: 23
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005445 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3823
# [LightGBM] [Info] Number of data points in the train set: 38646, number of used features: 23
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003294 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3822
# [LightGBM] [Info] Number of data points in the train set: 38689, number of used features: 23
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3820
# [LightGBM] [Info] Number of data points in the train set: 38687, number of used features: 23
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
# 预测结果重新排序, 及生成提交结果
# 单模型生成提交结果
rank_results = tst_user_item_feats_df_rank_model[['user_id', 'click_article_id', 'pred_score']]
rank_results['click_article_id'] = rank_results['click_article_id'].astype(int)
submit(rank_results, topk=5, model_name='lgb_ranker')

# %% [markdown]
# ---
#
# ## 4 LGB 分类模型

# %%
# 模型及参数的定义
lgb_Classfication = lgb.LGBMClassifier(boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=1,
                            max_depth=-1, n_estimators=500, subsample=0.7, colsample_bytree=0.7, subsample_freq=1,
                            learning_rate=0.01, min_child_weight=50, random_state=2018, n_jobs= 16, verbose=10)

# %%
# 模型训练
if offline:
    lgb_Classfication.fit(trn_user_item_feats_df_rank_model[lgb_cols], trn_user_item_feats_df_rank_model['label'],
                    eval_set=[(val_user_item_feats_df_rank_model[lgb_cols], val_user_item_feats_df_rank_model['label'])], 
                    eval_metric=['auc', ],early_stopping_rounds=50, )
else:
    lgb_Classfication.fit(trn_user_item_feats_df_rank_model[lgb_cols], trn_user_item_feats_df_rank_model['label'])
# Out:
# [LightGBM] [Info] Number of positive: 835, number of negative: 47548
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.877411
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.381483
# [LightGBM] [Debug] init for col-wise cost 0.002857 seconds, init for row-wise cost 0.006472 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003793 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 3839
# [LightGBM] [Info] Number of data points in the train set: 48383, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.017258 -> initscore=-4.042063
# [LightGBM] [Info] Start training from score -4.042063
# [LightGBM] [Debug] Re-bagging, using 33877 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34066 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33735 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33785 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33857 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34147 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33817 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33898 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33781 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33927 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33728 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33742 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33838 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34006 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33878 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33919 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33984 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33876 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 33897 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33943 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 6
# [LightGBM] [Debug] Re-bagging, using 33774 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33931 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33869 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34120 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33882 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34131 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33895 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33652 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33799 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33755 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33745 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33914 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33753 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33669 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34179 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33881 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33901 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33895 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33936 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33911 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33978 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33842 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33830 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34070 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33957 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34001 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33803 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33896 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33974 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33826 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33668 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33823 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33918 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33915 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34026 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33910 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33839 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33880 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33759 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34110 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33935 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33946 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33916 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33752 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33955 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33816 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33784 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33890 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33822 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33768 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33902 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33767 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33874 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33828 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33826 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33861 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33754 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33793 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34064 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33756 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34028 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33879 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33953 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33784 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33868 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33846 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33946 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33702 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33656 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33911 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33804 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33927 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33808 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33934 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33881 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33828 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33764 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33541 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33748 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33872 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33765 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33800 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33902 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33832 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33831 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33887 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33880 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33809 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33858 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33898 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34016 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33962 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34004 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33805 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33743 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34102 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33883 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33932 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33892 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34083 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33900 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33973 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33871 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33721 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33915 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33879 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33942 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33999 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34036 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33952 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33888 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33729 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33984 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33899 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33912 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33669 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33776 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33929 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34050 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34010 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33887 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33955 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33902 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33876 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33708 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33870 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33879 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33891 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33764 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33751 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33870 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33879 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33759 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33908 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33770 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33846 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33893 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33876 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33980 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33770 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33946 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33855 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33900 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33967 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33839 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34129 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33889 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33865 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33967 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33917 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34049 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33899 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33815 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34022 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33629 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33939 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33786 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33975 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33969 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33969 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33857 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33856 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33730 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33835 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33817 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33975 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33984 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33865 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33965 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33860 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33811 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33878 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33805 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33886 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33973 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33985 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33857 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33695 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33595 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33941 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33883 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33724 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33864 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33769 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33869 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33806 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33999 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33825 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33924 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33804 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33859 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33910 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33889 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33796 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33807 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33812 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33668 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33979 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33880 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33921 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33707 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33842 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33987 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33781 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33703 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33850 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 8 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33868 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33942 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33881 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33924 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33742 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33894 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33967 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34010 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33825 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33941 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33802 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33827 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33908 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33752 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33696 data to train
# ...
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33946 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33969 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33906 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33861 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33817 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33659 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33759 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33793 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33631 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33850 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33722 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33882 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33873 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33715 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33851 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33596 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33930 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33884 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33745 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33825 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33982 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33824 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33940 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33886 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33962 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33725 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34016 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33704 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33784 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33848 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34055 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33788 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33817 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33812 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33952 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 6
# [LightGBM] [Debug] Re-bagging, using 33821 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33796 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34113 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33758 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33919 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33844 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33852 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 34019 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33793 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33918 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33900 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33628 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33781 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33766 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33901 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33924 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33832 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33813 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33914 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33962 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33911 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 34025 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33840 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33648 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33806 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 34033 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33792 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33867 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33725 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33831 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33819 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33769 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33932 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33772 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 33757 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33916 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33813 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33784 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33852 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33748 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33942 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33900 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33657 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 33682 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33810 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 33889 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3

# %%
# 模型预测
tst_user_item_feats_df['pred_score'] = lgb_Classfication.predict_proba(tst_user_item_feats_df[lgb_cols])[:,1]

# 将这里的排序结果保存一份，用户后面的模型融合
tst_user_item_feats_df[['user_id', 'click_article_id', 'pred_score']].to_csv(rank_path + 'lgb_cls_score.csv', index=False)

# %%
# 诊断：检查数据分布和标签分布
print("=" * 50)
print("数据诊断")
print("=" * 50)

# 检查标签分布
print(f"\n标签分布:")
print(f"  正样本 (label=1): {(y == 1).sum()} ({(y == 1).mean() * 100:.2f}%)")
print(f"  负样本 (label=0): {(y == 0).sum()} ({(y == 0).mean() * 100:.2f}%)")
print(f"  标签范围: [{y.min()}, {y.max()}]")

# 检查输入特征
print(f"\n输入特征检查:")
for key, val in x.items():
    if isinstance(val, np.ndarray):
        if val.dtype in [np.float32, np.float64]:
            nan_count = np.isnan(val).sum()
            inf_count = np.isinf(val).sum()
            if nan_count > 0 or inf_count > 0:
                print(f"  {key}: ⚠️  NaN={nan_count}, Inf={inf_count}")
            else:
                print(f"  {key}: ✓ shape={val.shape}, min={val.min():.4f}, max={val.max():.4f}, mean={val.mean():.4f}")
        else:
            print(f"  {key}: ✓ shape={val.shape}, dtype={val.dtype}, min={val.min()}, max={val.max()}")

print("\n" + "=" * 50)

# %%
# 预测结果重新排序, 及生成提交结果
rank_results = tst_user_item_feats_df[['user_id', 'click_article_id', 'pred_score']]
rank_results['click_article_id'] = rank_results['click_article_id'].astype(int)
submit(rank_results, topk=5, model_name='lgb_cls')

# %%
# 五折交叉验证，这里的五折交叉是以用户为目标进行五折划分
#  这一部分与前面的单独训练和验证是分开的
def get_kfold_users(trn_df, n=5):
    user_ids = trn_df['user_id'].unique()
    user_set = [user_ids[i::n] for i in range(n)]
    return user_set

k_fold = 5
trn_df = trn_user_item_feats_df_rank_model
user_set = get_kfold_users(trn_df, n=k_fold)

score_list = []
score_df = trn_df[['user_id', 'click_article_id', 'label']]
sub_preds = np.zeros(tst_user_item_feats_df_rank_model.shape[0])

# 五折交叉验证，并将中间结果保存用于staking
for n_fold, valid_user in enumerate(user_set):
    train_idx = trn_df[~trn_df['user_id'].isin(valid_user)] # add slide user
    valid_idx = trn_df[trn_df['user_id'].isin(valid_user)]
    
    # 模型及参数的定义
    lgb_Classfication = lgb.LGBMClassifier(boosting_type='gbdt', num_leaves=31, reg_alpha=0.0, reg_lambda=1,
                            max_depth=-1, n_estimators=100, subsample=0.7, colsample_bytree=0.7, subsample_freq=1,
                            learning_rate=0.01, min_child_weight=50, random_state=2018, n_jobs= 16, verbose=10)  
    # 训练模型
    lgb_Classfication.fit(train_idx[lgb_cols], train_idx['label'],eval_set=[(valid_idx[lgb_cols], valid_idx['label'])], 
                          eval_metric=['auc', ])
    
    # 预测验证集结果
    valid_idx['pred_score'] = lgb_Classfication.predict_proba(valid_idx[lgb_cols], 
                                                              num_iteration=lgb_Classfication.best_iteration_)[:,1]
    
    # 对输出结果进行归一化 分类模型输出的值本身就是一个概率值不需要进行归一化
    # valid_idx['pred_score'] = valid_idx[['pred_score']].transform(lambda x: norm_sim(x))
    
    valid_idx.sort_values(by=['user_id', 'pred_score'])
    valid_idx['pred_rank'] = valid_idx.groupby(['user_id'])['pred_score'].rank(ascending=False, method='first')
    
    # 将验证集的预测结果放到一个列表中，后面进行拼接
    score_list.append(valid_idx[['user_id', 'click_article_id', 'pred_score', 'pred_rank']])
    
    # 如果是线上测试，需要计算每次交叉验证的结果相加，最后求平均
    if not offline:
        sub_preds += lgb_Classfication.predict_proba(tst_user_item_feats_df_rank_model[lgb_cols], 
                                                     num_iteration=lgb_Classfication.best_iteration_)[:,1]
    
score_df_ = pd.concat(score_list, axis=0)
score_df = score_df.merge(score_df_, how='left', on=['user_id', 'click_article_id'])
# 保存训练集交叉验证产生的新特征
score_df[['user_id', 'click_article_id', 'pred_score', 'pred_rank', 'label']].to_csv(save_path + 'trn_lgb_cls_feats.csv', index=False)
    
# 测试集的预测结果，多次交叉验证求平均，将预测的 score 和对应的 rank 特征保存，可以用于后面的 staking，这里还可以构造其他更多的特征
tst_user_item_feats_df_rank_model['pred_score'] = sub_preds / k_fold
tst_user_item_feats_df_rank_model['pred_score'] = tst_user_item_feats_df_rank_model['pred_score'].transform(lambda x: norm_sim(x))
tst_user_item_feats_df_rank_model.sort_values(by=['user_id', 'pred_score'])
tst_user_item_feats_df_rank_model['pred_rank'] = tst_user_item_feats_df_rank_model.groupby(['user_id'])['pred_score'].rank(ascending=False, method='first')

# 保存测试集交叉验证的新特征
tst_user_item_feats_df_rank_model[['user_id', 'click_article_id', 'pred_score', 'pred_rank']].to_csv(save_path + 'tst_lgb_cls_feats.csv', index=False)
# Out:
# [LightGBM] [Info] Number of positive: 677, number of negative: 38095
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.876921
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.381270
# [LightGBM] [Debug] init for col-wise cost 0.001713 seconds, init for row-wise cost 0.003705 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002368 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 3822
# [LightGBM] [Info] Number of data points in the train set: 38772, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.017461 -> initscore=-4.030167
# [LightGBM] [Info] Start training from score -4.030167
# [LightGBM] [Debug] Re-bagging, using 27170 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27279 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27034 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26994 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27147 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27330 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27078 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27112 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27075 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27207 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27017 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27059 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27133 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27273 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27117 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27233 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27244 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27167 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27175 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27231 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27085 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27224 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27112 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27315 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27160 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27403 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27205 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26964 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27028 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27129 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26958 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27166 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27017 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27047 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27408 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27046 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27163 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27201 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27124 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27152 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27211 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27091 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27013 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27282 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27184 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27212 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27083 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27161 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27219 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27067 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26998 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27140 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27208 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27166 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27294 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27133 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27137 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27147 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26991 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27383 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27150 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27199 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27150 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27029 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27254 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27171 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27050 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27135 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27016 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27071 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27168 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27126 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27129 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27101 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27146 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27088 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27092 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27048 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27215 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26950 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27322 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27168 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27183 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27134 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27083 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27097 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27227 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26985 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26952 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27236 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27124 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27125 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26985 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27264 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27205 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27138 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27053 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26861 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27034 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27053 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Info] Number of positive: 685, number of negative: 38053
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.875936
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.380842
# [LightGBM] [Debug] init for col-wise cost 0.001514 seconds, init for row-wise cost 0.003543 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002072 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 3828
# [LightGBM] [Info] Number of data points in the train set: 38738, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.017683 -> initscore=-4.017316
# [LightGBM] [Info] Start training from score -4.017316
# [LightGBM] [Debug] Re-bagging, using 27147 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27263 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27002 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26973 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27118 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27320 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27040 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27091 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27035 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27204 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26985 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27038 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27106 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27237 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27102 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27208 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27223 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27123 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27172 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27202 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27072 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27186 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27098 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27296 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27103 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27399 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27169 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26969 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27001 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27077 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26985 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27131 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 26979 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27026 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27371 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27061 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27135 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27151 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27109 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27132 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27158 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27081 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27024 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27246 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27138 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27162 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27085 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27146 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27173 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27039 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 26976 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27116 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27202 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27137 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27251 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27117 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27103 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27122 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27013 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27373 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27104 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27183 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27096 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26991 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27225 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27167 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27043 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27088 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27008 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27069 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27137 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27094 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27095 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27089 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27102 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27066 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27063 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27029 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27203 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26919 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27304 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27125 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27167 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27090 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27079 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27092 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27254 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26942 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26893 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27200 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27054 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27129 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26963 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27258 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27164 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27115 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27046 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26850 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27001 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27023 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Info] Number of positive: 646, number of negative: 38000
# [LightGBM] [Debug] Dataset::GetMultiBinFromSparseFeatures: sparse rate 0.879126
# [LightGBM] [Debug] Dataset::GetMultiBinFromAllFeatures: sparse rate 0.382229
# [LightGBM] [Debug] init for col-wise cost 0.001548 seconds, init for row-wise cost 0.003342 seconds
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Debug] Using Sparse Multi-Val Bin
# [LightGBM] [Info] Total Bins 3823
# [LightGBM] [Info] Number of data points in the train set: 38646, number of used features: 23
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.016716 -> initscore=-4.074542
# [LightGBM] [Info] Start training from score -4.074542
# [LightGBM] [Debug] Re-bagging, using 27084 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27200 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26945 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26892 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27054 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27261 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26959 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27045 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26974 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27123 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26935 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26982 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27035 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27166 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27020 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27137 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27179 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27059 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27072 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27148 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27033 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27121 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27020 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27236 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27041 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27329 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27091 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26878 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26952 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27027 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26917 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27097 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27194 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27041 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27149 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27058 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27265 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27075 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27321 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27135 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26939 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26977 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27060 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26921 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 5
# [LightGBM] [Debug] Re-bagging, using 27121 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26982 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 3 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 26955 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27339 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27018 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27121 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27127 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27081 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27066 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 2
# [LightGBM] [Debug] Re-bagging, using 27132 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27038 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26960 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27213 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27128 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27143 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27013 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27099 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27140 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27014 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26925 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27078 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27152 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27108 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27216 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 7 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27074 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27077 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27086 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26961 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27331 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27100 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27157 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27084 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26974 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27155 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 4 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27111 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26988 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27068 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26966 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27033 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27114 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27069 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27069 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27034 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27077 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27046 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27016 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 26968 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27171 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26891 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27248 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27097 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27137 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27055 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27039 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27059 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27199 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26911 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26874 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 5 and depth = 3
# [LightGBM] [Debug] Re-bagging, using 27177 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27071 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27061 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26937 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27189 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27126 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 27046 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26989 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26836 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26969 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4
# [LightGBM] [Debug] Re-bagging, using 26995 data to train
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Debug] Trained a tree with leaves = 6 and depth = 4

# %%
# 预测结果重新排序, 及生成提交结果
rank_results = tst_user_item_feats_df_rank_model[['user_id', 'click_article_id', 'pred_score']]
rank_results['click_article_id'] = rank_results['click_article_id'].astype(int)
submit(rank_results, topk=5, model_name='lgb_cls')

# %% [markdown]
# ---
#
# ## 5 DIN 模型
#
# ### 5.1 用户的历史点击行为列表
#
# 这个是为后面的DIN模型服务的。

# %%
if offline:
    all_data = pd.read_csv('./data/train_click_log.csv')
else:
    trn_data = pd.read_csv('./data/train_click_log.csv')
    tst_data = pd.read_csv('./data/testA_click_log.csv')
    all_data = pd.concat([trn_data, tst_data], ignore_index=True)

# %%
hist_click = all_data[['user_id', 'click_article_id']].groupby('user_id').agg({list}).reset_index()
his_behavior_df = pd.DataFrame()
his_behavior_df['user_id'] = hist_click['user_id']
his_behavior_df['hist_click_article_id'] = hist_click['click_article_id']

# %%
trn_user_item_feats_df_din_model = trn_user_item_feats_df.copy()

if offline:
    val_user_item_feats_df_din_model = val_user_item_feats_df.copy()
else: 
    val_user_item_feats_df_din_model = None
    
tst_user_item_feats_df_din_model = tst_user_item_feats_df.copy()

# %%
trn_user_item_feats_df_din_model = trn_user_item_feats_df_din_model.merge(his_behavior_df, on='user_id')

if offline:
    val_user_item_feats_df_din_model = val_user_item_feats_df_din_model.merge(his_behavior_df, on='user_id')
else:
    val_user_item_feats_df_din_model = None

tst_user_item_feats_df_din_model = tst_user_item_feats_df_din_model.merge(his_behavior_df, on='user_id')

# %%
trn_user_item_feats_df_din_model
# Out:
#        user_id  click_article_id      sim0    time_diff0  word_diff0  \
# 0            0              3244       NaN           NaN         NaN
# 1            5              8603       NaN           NaN         NaN
# 2            6              8017       NaN           NaN         NaN
# 3            6             10243       NaN           NaN         NaN
# 4           18              8609       NaN           NaN         NaN
# ...        ...               ...       ...           ...         ...
# 48378   199958              8609       NaN           NaN         NaN
# 48379   199961              1330       NaN           NaN         NaN
# 48380   199975               598  0.449289  8.110598e+10        55.0
# 48381   199988              8710       NaN           NaN         NaN
# 48382   199997              8603       NaN           NaN         NaN
#
#         sim_max   sim_min   sim_sum  sim_mean     score  ...  click_region  \
# 0           NaN       NaN  0.000000       NaN  0.375211  ...            25
# 1           NaN       NaN  0.000000       NaN       NaN  ...            25
# 2           NaN       NaN  0.000000       NaN  0.078042  ...             2
# 3           NaN       NaN  0.000000       NaN  0.173251  ...             2
# 4           NaN       NaN  0.000000       NaN  0.000000  ...            13
# ...         ...       ...       ...       ...       ...  ...           ...
# 48378       NaN       NaN  0.000000       NaN  0.000000  ...            10
# 48379       NaN       NaN  0.000000       NaN  0.000000  ...            20
# 48380  0.449289  0.449289  0.449289  0.449289  0.000000  ...            25
# 48381       NaN       NaN  0.000000       NaN       NaN  ...            28
# 48382       NaN       NaN  0.000000       NaN       NaN  ...            16
#
#        click_referrer_type  user_time_hob1  user_time_hob2   words_hbo  \
# 0                        2        0.343715        0.992865  266.000000
# 1                        2        0.343598        0.992789  226.000000
# 2                        1        0.343844        0.991332  188.500000
# 3                        1        0.343844        0.991332  188.500000
# 4                        2        0.343523        0.992784  197.500000
# ...                    ...             ...             ...         ...
# 48378                    1        0.228723        0.990938  220.562500
# 48379                    1        0.191252        0.991104  209.250000
# 48380                    2        0.178436        0.990914  197.736842
# 48381                    2        0.019358        0.989220  251.500000
# 48382                    1        0.019385        0.989068  174.500000
#
#        category_id  created_at_ts  words_count  is_cat_hab  \
# 0                1  1508220059000          153           0
# 1                6  1491484758000          164           0
# 2                6  1515513946000          240           0
# 3                6  1507990586000          233           0
# 4                6  1506106322000          174           0
# ...            ...            ...          ...         ...
# 48378            6  1506106322000          174           0
# 48379            1  1471301725000          187           0
# 48380            1  1426443309000          143           0
# 48381            6  1519057619000          164           0
# 48382            6  1491484758000          164           0
#
#                                    hist_click_article_id
# 0                                        [30760, 157507]
# 1                                       [211442, 234481]
# 2                                         [62464, 10023]
# 3                                         [62464, 10023]
# 4                                        [70986, 224730]
# ...                                                  ...
# 48378  [70755, 111809, 158915, 293432, 36399, 70214, ...
# 48379  [64329, 199198, 265993, 313431, 199197, 214129...
# 48380  [336476, 272143, 79454, 175213, 119193, 119046...
# 48381                                   [156624, 160974]
# 48382                                   [224171, 223931]
#
# [48383 rows x 29 columns]

# %% [markdown]
# ### 5.2 DIN 模型介绍
#
# 我们下面尝试使用 DIN 模型，DIN 的全称是 Deep Interest Network，这是阿里 2018 年基于前面的深度学习模型无法表达用户多样化的兴趣而提出的一个模型，它可以通过考虑【给定的候选广告】和【用户的历史行为】的相关性，来计算用户兴趣的表示向量。
#
# 具体来说就是通过<font color=red>引入局部激活单元，通过软搜索历史行为的相关部分来关注相关的用户兴趣，并采用加权和来获得有关候选广告的用户兴趣的表示</font>。与候选广告相关性较高的行为会获得较高的激活权重，并支配着用户兴趣。
#
# 该表示向量在不同广告上有所不同，大大提高了模型的表达能力。所以该模型对于此次新闻推荐的任务也比较适合，我们在这里通过当前的候选文章与用户历史点击文章的相关性来计算用户对于文章的兴趣。
#
# 该模型的结构如下：
#
# <img src="../image/din.png">
#
# 我们这里直接调包来使用这个模型，关于这个模型的详细细节部分我们会在下一期的推荐系统组队学习中给出。下面说一下该模型如何具体使用。
#
# deepctr 的函数原型如下：
#
# > def DIN(dnn_feature_columns, history_feature_list, dnn_use_bn=False, dnn_hidden_units=(200, 80), dnn_activation='relu', att_hidden_size=(80, 40), att_activation="dice", att_weight_normalization=False, l2_reg_dnn=0, l2_reg_embedding=1e-6, dnn_dropout=0, seed=1024, task='binary'):
#
# - `dnn_feature_columns`：特征列，包含数据所有特征的列表
# - `history_feature_list`：用户历史行为列，反应用户历史行为的特征的列表
# - `dnn_use_bn`：是否使用 BatchNormalization
# - `dnn_hidden_units`：全连接层网络的层数和每一层神经元的个数， 一个列表或者元组
# - `dnn_activation_relu`：全连接网络的激活单元类型
# - `att_hidden_size`：注意力层的全连接网络的层数和每一层神经元的个数
# - `att_activation`：注意力层的激活单元类型
# - `att_weight_normalization`：是否归一化注意力得分
# - `l2_reg_dnn`：全连接网络的正则化系数
# - `l2_reg_embedding`：embedding向量的正则化稀疏
# - `dnn_dropout`：全连接网络的神经元的失活概率
# - `task`：任务，可以是分类，也可是是回归
#
# 在具体使用的时候，我们必须要传入特征列和历史行为列，但是再传入之前，我们需要进行一下特征列的预处理。具体如下：
#
# 首先，我们要处理数据集得到数据，由于我们是基于用户过去的行为去预测用户是否点击当前文章，所以我们需要把数据的特征列划分成数值型特征、离散型特征和历史行为特征列三部分，对于每一部分，DIN 模型的处理会有不同。
#
# #### 5.2.1 离散型特征
#
# 在我们的数据集中就是那些类别型的特征，比如 user_id 这种，这种类别型特征，我们首先要经过 Embedding 处理得到每个特征的低维稠密型表示，既然要经过 Embedding，那么我们就需要为每一列的类别特征的取值建立一个字典，并指明 Embedding 维度，所以在使用 deepctr 的 DIN 模型准备数据的时候，我们需要通过 SparseFeat 函数指明这些类别型特征，这个函数的传入参数就是列名，列的唯一取值（建立字典用）和 Embedding 维度。
#
# #### 5.2.2 用户历史行为特征
#
# 比如文章 id，文章的类别等这种，同样的我们需要先经过 Embedding 处理。只不过和上面不一样的地方是，对于这种特征，我们在得到每个特征的 Embedding 表示之后，还需要通过一个 Attention_layer 计算用户的历史行为和当前候选文章的相关性以此得到当前用户的 Embedding 向量。
#
# 这个向量就可以基于当前的候选文章与用户过去点击过得历史文章的相似性的程度来反应用户的兴趣，并且随着用户的不同的历史点击来变化，去动态的模拟用户兴趣的变化过程。
#
# 这类特征对于每个用户都是一个历史行为序列，对于每个用户，历史行为序列长度会不一样，可能有的用户点击的历史文章多，有的点击的历史文章少，所以我们还需要把这个长度统一起来。
#
# 在为 DIN 模型准备数据的时候，我们首先要通过 SparseFeat 函数指明这些类别型特征，然后还需要通过 VarLenSparseFeat 函数再进行序列填充，使得每个用户的历史序列一样长，所以这个函数参数中会有个 maxlen，来指明序列的最大长度是多少。
#
# #### 5.2.3 连续型特征列
#
# 对于连续型特征列，只需要用 DenseFeat 函数来指明列名和维度即可。
#
# 处理完特征列之后，我们把相应的数据与列进行对应，就得到了最后的数据。
#
# 下面根据具体的代码感受一下，逻辑是这样，首先我们需要写一个数据准备函数，在这里面就是根据上面的具体步骤准备数据，得到数据和特征列，然后就是建立 DIN 模型并训练，最后基于模型进行测试。
#
# ---
#
# ## 5.3 导包

# %%
# 导入deepctr
from deepctr.models import DIN
from tensorflow.keras.preprocessing.sequence import pad_sequences
from deepctr.feature_column import SparseFeat, VarLenSparseFeat, DenseFeat, get_feature_names

import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import * 
from tensorflow.keras import backend as K

from sklearn.preprocessing import MinMaxScaler

try:
    from tensorflow.python.distribute import input_lib
    if not hasattr(input_lib, 'DistributedDatasetInterface'):
        if hasattr(input_lib, 'DistributedDataset'):
            input_lib.DistributedDatasetInterface = input_lib.DistributedDataset
        else:
            class DistributedDatasetInterface:
                pass
            input_lib.DistributedDatasetInterface = DistributedDatasetInterface
except Exception as e:
    print(f"Warning: Could not fix DistributedDatasetInterface: {e}")

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
# Out:
# 2025-12-24 14:47:21.609129: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-24 14:47:21.659900: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-24 14:47:21.659947: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-24 14:47:21.661767: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-24 14:47:21.670609: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-24 14:47:22.544878: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def get_din_feats_columns(df: pd.DataFrame, 
                          dense_fea: list, 
                          sparse_fea: list, 
                          behavior_fea: list, 
                          his_behavior_fea: list, 
                          emb_dim: int = 32, 
                          max_len: int = 100) -> tuple:
    """
    数据准备函数，用于构建 Deep Interest Network (DIN) 的输入特征。

    Args:
        df (`pd.DataFrame`): 输入的数据集。
        dense_fea (`list`): 数值型特征列的名称列表。
        sparse_fea (`list`): 离散型特征列的名称列表。
        behavior_fea (`list`): 用户的候选行为特征列名称列表。
        his_behavior_fea (`list`): 用户的历史行为特征列名称列表。
        emb_dim (`int`, optional): embedding 的维度，默认为 32。
        max_len (`int`, optional): 用户序列的最大长度，默认为 100。

    Returns:
        `tuple`: 包含两个元素的元组：
            - `x`: 特征字典，包含模型输入特征。
            - `dnn_feature_columns`: DNN 特征列的列表。
    """
    # 构建离散特征列，添加 vocabulary_size 和 embedding_dim
    sparse_feature_columns = [SparseFeat(feat, vocabulary_size=df[feat].max() + 1, embedding_dim=emb_dim) for feat in sparse_fea]

    # 构建密集特征列
    dense_feature_columns = [DenseFeat(feat, 1) for feat in dense_fea]

    # 构建变长离散特征列
    var_feature_columns = [VarLenSparseFeat(SparseFeat(feat, vocabulary_size=df['click_article_id'].max() + 1,
                                    embedding_dim=emb_dim, embedding_name='click_article_id'), maxlen=max_len) for feat in his_behavior_fea]
    
    # 合并所有特征列
    dnn_feature_columns = sparse_feature_columns + dense_feature_columns + var_feature_columns
    
    # 初始化特征字典
    x = {}
    for name in get_feature_names(dnn_feature_columns):
        if name in his_behavior_fea:
            # 处理历史行为序列，进行填充以满足最大长度
            his_list = [l for l in df[name]]
            x[name] = pad_sequences(his_list, maxlen=max_len, padding='post')  # 生成二维数组
        else:
            x[name] = df[name].values  # 直接提取特征列的值

    return x, dnn_feature_columns  # 返回特征字典和特征列列表

# %%
# 把特征分开
sparse_fea = ['user_id', 'click_article_id', 'category_id', 'click_environment', 'click_deviceGroup', 
              'click_os', 'click_country', 'click_region', 'click_referrer_type', 'is_cat_hab']

behavior_fea = ['click_article_id']

hist_behavior_fea = ['hist_click_article_id']

dense_fea = ['sim0', 'time_diff0', 'word_diff0', 'sim_max', 'sim_min', 'sim_sum', 'sim_mean', 'score',
             'rank','click_size','time_diff_mean','active_level','user_time_hob1','user_time_hob2',
             'words_hbo','words_count']

# %%
trn_user_item_feats_df_din_model['hist_click_article_id']
# Out:
# 0                                          [30760, 157507]
# 1                                         [211442, 234481]
# 2                                           [62464, 10023]
# 3                                           [62464, 10023]
# 4                                          [70986, 224730]
#                                ...
# 48378    [70755, 111809, 158915, 293432, 36399, 70214, ...
# 48379    [64329, 199198, 265993, 313431, 199197, 214129...
# 48380    [336476, 272143, 79454, 175213, 119193, 119046...
# 48381                                     [156624, 160974]
# 48382                                     [224171, 223931]
# Name: hist_click_article_id, Length: 48383, dtype: object

# %%
# dense特征进行归一化, 神经网络训练都需要将数值进行归一化处理
mm = MinMaxScaler()

# 下面是做一些特殊处理，当在其他的地方出现无效值的时候，不处理无法进行归一化，刚开始可以先把他注释掉
# 在运行了下面的代码之后如果发现报错，应该先去想办法处理如何不出现inf之类的值
trn_user_item_feats_df_din_model.replace([np.inf, -np.inf], 0, inplace=True)
tst_user_item_feats_df_din_model.replace([np.inf, -np.inf], 0, inplace=True)

for feat in dense_fea:
    trn_user_item_feats_df_din_model[feat] = mm.fit_transform(trn_user_item_feats_df_din_model[[feat]])
    
    if val_user_item_feats_df_din_model is not None:
        val_user_item_feats_df_din_model[feat] = mm.fit_transform(val_user_item_feats_df_din_model[[feat]])
    
    tst_user_item_feats_df_din_model[feat] = mm.fit_transform(tst_user_item_feats_df_din_model[[feat]])

# %%
import numpy as np
import torch

import pandas as pd
from tensorflow.keras.preprocessing.sequence import pad_sequences

from funrec.inputs import DenseFeat, SparseFeat, VarLenSparseFeat, get_feature_names
from funrec.models import DIN

# 配置参数
emb_dim = 8
max_len = 50

def build_feature_columns(sparse_fea, dense_fea, hist_behavior_fea, emb_dim, vocab_map):
    feature_columns = []

    # 稀疏特征
    for feat in sparse_fea:
        vocab_size = max(vocab_map[feat].values()) + 1 if vocab_map.get(feat) else 1
        feature_columns.append(
            SparseFeat(feat, vocabulary_size=vocab_size, embedding_dim=emb_dim)
        )

    # 稠密特征
    for feat in dense_fea:
        feature_columns.append(
            DenseFeat(feat, 1)
        )

    # 变长稀疏特征
    for hist_feat in hist_behavior_fea:
        emb_feat = 'click_article_id'
        vocab_size = max(vocab_map[emb_feat].values()) + 1 if vocab_map.get(emb_feat) else 1
        feature_columns.append(
            VarLenSparseFeat(
                SparseFeat(hist_feat, vocabulary_size=vocab_size, embedding_dim=emb_dim, embedding_name=emb_feat),
                maxlen=max_len,
                combiner="mean",
                length_name=f"{hist_feat}_len"
            )
        )
    return feature_columns

def map_ids(df, feature, mapping):
    return df[feature].astype('int64').map(mapping).fillna(0).astype('int32').values

def map_seq(seq_list, mapping):
    mapped_seq = []
    seq_lens = []
    for seq in seq_list:
        if isinstance(seq, (list, np.ndarray)):
            mapped = [mapping.get(int(x), 0) if int(x) != 0 else 0 for x in seq]
            mapped_seq.append(mapped)
            seq_lens.append(min(len(mapped), max_len))
        else:
            mapped_seq.append([0])
            seq_lens.append(0)
    padded_seq = pad_sequences(mapped_seq, maxlen=max_len, padding='post').astype('int32')
    return padded_seq, np.array(seq_lens, dtype='int32')

def build_vocab_map(dfs, sparse_fea):
    vocab_map = {}
    for feat in sparse_fea:
        vals = pd.concat([df[feat].astype('int64') for df in dfs], ignore_index=True)
        if feat == 'click_article_id':
            seq_vals = []
            for df in dfs:
                if 'hist_click_article_id' in df.columns:
                    for seq in df['hist_click_article_id']:
                        if isinstance(seq, (list, np.ndarray)):
                            seq_vals.extend([int(x) for x in seq])
            if len(seq_vals) > 0:
                vals = pd.concat([vals, pd.Series(seq_vals, dtype='int64')], ignore_index=True)
        _, uniques = pd.factorize(vals, sort=False)
        mapping = {int(val): int(idx) for idx, val in enumerate(uniques)}
        # 保留0 for padding for 'click_article_id'
        if feat == 'click_article_id':
            mapping = {k: v + 1 for k, v in mapping.items()}
        vocab_map[feat] = mapping
    return vocab_map

def build_model_input(df, feature_columns, vocab_map):
    model_input = {}
    for feat in get_feature_names(feature_columns):
        if feat in sparse_fea:
            model_input[feat] = map_ids(df, feat, vocab_map[feat])
        elif feat in dense_fea:
            vals = df[feat].astype('float32').values
            # 处理 NaN 和 inf 值
            # 对于 NaN，使用该特征的均值填充，如果全为 NaN 则填充 0
            if np.isnan(vals).any():
                fill_value = np.nanmean(vals) if not np.isnan(np.nanmean(vals)) else 0.0
                vals = np.nan_to_num(vals, nan=fill_value, posinf=1.0, neginf=0.0)
            else:
                # 即使没有 NaN，也要处理 inf
                vals = np.nan_to_num(vals, nan=0.0, posinf=1.0, neginf=0.0)
            # 确保值在合理范围内（归一化后应该在 [0, 1]）
            vals = np.clip(vals, 0.0, 1.0)
            model_input[feat] = vals
        elif feat == 'hist_click_article_id':
            seqs, seq_lens = map_seq(df[feat].values, vocab_map['click_article_id'])
            model_input[feat] = seqs
            model_input[f"{feat}_len"] = seq_lens
    return model_input

def get_xy_fd_real():
    # 使用实际的train/test DataFrame
    df_trn = trn_user_item_feats_df_din_model
    df_tst = tst_user_item_feats_df_din_model

    df_val = val_user_item_feats_df_din_model if 'val_user_item_feats_df_din_model' in globals() and val_user_item_feats_df_din_model is not None else None

    dfs = [df_trn, df_tst] + ([df_val] if df_val is not None else [])
    vocab_map = build_vocab_map(dfs, sparse_fea)
    feature_columns = build_feature_columns(sparse_fea, dense_fea, hist_behavior_fea, emb_dim, vocab_map)
    behavior_feature_list = ['click_article_id']

    # train
    x = build_model_input(df_trn, feature_columns, vocab_map)
    y = df_trn['label'].values.astype('float32')

    # test
    x_test = build_model_input(df_tst, feature_columns, vocab_map)
    y_test = None  # 测试集无真实label

    return x, y, feature_columns, behavior_feature_list, x_test

# %%
x, y, feature_columns, behavior_feature_list, x_test = get_xy_fd_real()

device = "cpu"
use_cuda = True
if use_cuda and torch.cuda.is_available():
    print("cuda ready...")
    device = "cuda:0"

model = DIN(
    feature_columns,
    behavior_feature_list,
    device=device,
    att_weight_normalization=True,
)

import torch.nn as nn

class BCEWithLogitsLossWrapper(nn.Module):
    """包装 BCEWithLogitsLoss，忽略调用时的 reduction 参数"""
    def __init__(self, reduction="sum"):
        super().__init__()
        self.loss_fn = nn.BCEWithLogitsLoss(reduction=reduction)
    
    def forward(self, input, target, **kwargs):
        return self.loss_fn(input, target)

loss_fn = BCEWithLogitsLossWrapper(reduction="sum")
loss_fn = BCEWithLogitsLossWrapper(reduction="sum")

# 使用 Adam 优化器，学习率设为 0.001
import torch.optim as optim
optimizer = optim.Adam(model.parameters(), lr=0.001)
model.compile(optimizer, loss_fn, metrics=["bce_with_logits"])

# %%
x
# Out:
# {'user_id': array([    0,     1,     2, ..., 44667, 44668, 44669], dtype=int32),
#  'click_article_id': array([ 1,  2,  3, ..., 29,  8,  2], dtype=int32),
#  'category_id': array([0, 1, 1, ..., 0, 1, 1], dtype=int32),
#  'click_environment': array([0, 0, 0, ..., 0, 0, 0], dtype=int32),
#  'click_deviceGroup': array([0, 1, 2, ..., 2, 2, 0], dtype=int32),
#  'click_os': array([0, 1, 1, ..., 1, 3, 0], dtype=int32),
#  'click_country': array([0, 0, 0, ..., 0, 4, 0], dtype=int32),
#  'click_region': array([ 0,  0,  1, ...,  0, 15,  9], dtype=int32),
#  'click_referrer_type': array([0, 0, 1, ..., 0, 0, 1], dtype=int32),
#  'is_cat_hab': array([0, 0, 0, ..., 0, 0, 0], dtype=int32),
#  'sim0': array([0.7439238 , 0.7439238 , 0.7439238 , ..., 0.58110964, 0.7439238 ,
#         0.7439238 ], dtype=float32),
#  'time_diff0': array([0.12182731, 0.12182731, 0.12182731, ..., 0.5445253 , 0.12182731,
#         0.12182731], dtype=float32),
#  'word_diff0': array([0.02569613, 0.02569613, 0.02569613, ..., 0.03647215, 0.02569613,
#         0.02569613], dtype=float32),
#  'sim_max': array([0.7439238 , 0.7439238 , 0.7439238 , ..., 0.58110964, 0.7439238 ,
#         0.7439238 ], dtype=float32),
#  'sim_min': array([0.7439238 , 0.7439238 , 0.7439238 , ..., 0.58110964, 0.7439238 ,
#         0.7439238 ], dtype=float32),
#  'sim_sum': array([0.23936461, 0.23936461, 0.23936461, ..., 0.58110964, 0.23936461,
#         0.23936461], dtype=float32),
#  'sim_mean': array([0.7439238 , 0.7439238 , 0.7439238 , ..., 0.58110964, 0.7439238 ,
#         0.7439238 ], dtype=float32),
#  'score': array([0.18760549, 0.03911079, 0.0390209 , ..., 0.        , 0.03911079,
#         0.03911079], dtype=float32),
#  'rank': array([0.  , 0.  , 0.  , ..., 0.  , 0.  , 0.25], dtype=float32),
#  'click_size': array([1.        , 1.        , 1.        , ..., 0.09491938, 1.        ,
#         1.        ], dtype=float32),
#  'time_diff_mean': array([3.962167e-05, 3.962167e-05, 3.962167e-05, ..., 8.780711e-02,
#         3.962167e-05, 3.962167e-05], dtype=float32),
#  'active_level': array([0.39662904, 0.39662904, 0.39662904, ..., 0.09539109, 0.39662904,
#         0.39662904], dtype=float32),
#  'user_time_hob1': array([4.8376498e-01, 4.8358956e-01, 4.8395661e-01, ..., 2.3725884e-01,
#         0.0000000e+00, 4.1355463e-05], dtype=float32),
#  'user_time_hob2': array([0.9943178 , 0.99419814, 0.991923  , ..., 0.9912704 , 0.9886253 ,
#         0.98838836], dtype=float32),
#  'words_hbo': array([0.17088175, 0.14354067, 0.11790841, ..., 0.12422204, 0.16097061,
#         0.10833903], dtype=float32),
#  'words_count': array([0.0752884 , 0.08196721, 0.12811172, ..., 0.06921676, 0.08196721,
#         0.08196721], dtype=float32),
#  'hist_click_article_id': array([[ 5086,  5087,     0, ...,     0,     0,     0],
#         [ 5088,  5089,     0, ...,     0,     0,     0],
#         [ 5090,  4039,     0, ...,     0,     0,     0],
#         ...,
#         [15314, 10163,  8625, ...,     0,     0,     0],
#         [10053,  9938,     0, ...,     0,     0,     0],
#         [17950, 19369,     0, ...,     0,     0,     0]], dtype=int32),
#  'hist_click_article_id_len': array([ 2,  2,  2, ..., 19,  2,  2], dtype=int32)}

# %%
history = model.fit(x, y, batch_size=128, epochs=20, verbose=2, validation_split=0.2)
# Out:
# 2025-12-24 15:13:38.930 |INFO    | funrec.models.base.base : base: 175 | funrec | - cpu
# 2025-12-24 15:13:38.931 |INFO    | funrec.models.base.base : base: 195 | funrec | - Train on 38706 samples, validate on 9677 samples, 303 steps per epoch
# 2025-12-24 15:13:45.729 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 1/20
# 2025-12-24 15:13:45.730 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 6s - loss:  0.7110
# 2025-12-24 15:13:52.478 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 2/20
# 2025-12-24 15:13:52.480 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 6s - loss:  0.6932
# 2025-12-24 15:13:59.205 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 3/20
# 2025-12-24 15:13:59.206 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 6s - loss:  0.6932
# 2025-12-24 15:14:06.219 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 4/20
# 2025-12-24 15:14:06.220 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6932
# 2025-12-24 15:14:13.613 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 5/20
# 2025-12-24 15:14:13.614 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6931
# 2025-12-24 15:14:20.814 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 6/20
# 2025-12-24 15:14:20.815 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6929
# 2025-12-24 15:14:27.946 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 7/20
# 2025-12-24 15:14:27.947 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6925
# 2025-12-24 15:14:35.096 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 8/20
# 2025-12-24 15:14:35.097 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6920
# 2025-12-24 15:14:42.174 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 9/20
# 2025-12-24 15:14:42.175 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6912
# 2025-12-24 15:14:49.228 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 10/20
# 2025-12-24 15:14:49.229 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6906
# 2025-12-24 15:14:56.357 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 11/20
# 2025-12-24 15:14:56.359 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6897
# 2025-12-24 15:15:03.568 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 12/20
# 2025-12-24 15:15:03.569 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6890
# 2025-12-24 15:15:10.711 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 13/20
# 2025-12-24 15:15:10.713 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6882
# 2025-12-24 15:15:17.923 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 14/20
# 2025-12-24 15:15:17.924 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6877
# 2025-12-24 15:15:24.986 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 15/20
# 2025-12-24 15:15:24.988 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6875
# 2025-12-24 15:15:31.989 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 16/20
# 2025-12-24 15:15:31.990 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6873
# 2025-12-24 15:15:39.081 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 17/20
# 2025-12-24 15:15:39.083 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6872
# 2025-12-24 15:15:46.083 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 18/20
# 2025-12-24 15:15:46.084 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 6s - loss:  0.6871
# 2025-12-24 15:15:53.212 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 19/20
# 2025-12-24 15:15:53.214 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6870
# 2025-12-24 15:16:00.325 |INFO    | funrec.models.base.base : base: 265 | funrec | - Epoch 20/20
# 2025-12-24 15:16:00.326 |SUCCESS | funrec.models.base.base : base: 282 | funrec | - 7s - loss:  0.6870

# %%
# 预测
pred_score = model.predict(x_test, batch_size=256)
tst_user_item_feats_df_din_model['pred_score'] = pred_score
tst_user_item_feats_df_din_model[['user_id', 'click_article_id', 'pred_score']].to_csv(f"{rank_path}/din_rank_score.csv", index=False)
rank_results = tst_user_item_feats_df_din_model[['user_id', 'click_article_id', 'pred_score']]

# %%
# 预测结果重新排序, 及生成提交结果
submit(rank_results, topk=5, model_name='din')

# %% [markdown]
# ---
#
# ## 6 模型融合
#
# ### 6.1 加权融合

# %%
# 读取多个模型的排序结果文件
lgb_ranker = pd.read_csv(rank_path + 'lgb_ranker_score.csv')
lgb_cls = pd.read_csv(rank_path + 'lgb_cls_score.csv')
din_ranker = pd.read_csv(rank_path + 'din_rank_score.csv')

# %%
rank_model = {'lgb_ranker': lgb_ranker, 
              'lgb_cls': lgb_cls,
              'din_ranker': din_ranker}

# %%
def get_ensumble_predict_topk(rank_model, topk=5):
    # final_recall = rank_model['lgb_cls'].append(rank_model['din_ranker'])
    final_recall = pd.concat([rank_model['lgb_cls'], rank_model['din_ranker']]).reset_index(drop=True)
    rank_model['lgb_ranker']['pred_score'] = rank_model['lgb_ranker']['pred_score'].transform(lambda x: norm_sim(x))

    # final_recall = final_recall.append(rank_model['lgb_ranker'])
    final_recall = pd.concat([final_recall, rank_model['lgb_ranker']]).reset_index(drop=True)
    final_recall = final_recall.groupby(['user_id', 'click_article_id'])['pred_score'].sum().reset_index()

    submit(final_recall, topk=topk, model_name='ensemble_fuse')

# %%
get_ensumble_predict_topk(rank_model)

# %% [markdown]
# ### 6.2 Stacking
#
# - 读取多个模型的交叉验证生成的结果文件

# %%
# 训练集
trn_lgb_ranker_feats = pd.read_csv(save_path + 'trn_lgb_ranker_feats.csv')
trn_lgb_cls_feats = pd.read_csv(save_path + 'trn_lgb_cls_feats.csv')
trn_din_cls_feats = pd.read_csv(save_path + 'trn_din_cls_feats.csv')

# 测试集
tst_lgb_ranker_feats = pd.read_csv(save_path + 'tst_lgb_ranker_feats.csv')
tst_lgb_cls_feats = pd.read_csv(save_path + 'tst_lgb_cls_feats.csv')
tst_din_cls_feats = pd.read_csv(save_path + 'tst_din_cls_feats.csv')

# %%
# 将多个模型输出的特征进行拼接
finall_trn_ranker_feats = trn_lgb_ranker_feats[['user_id', 'click_article_id', 'label']]
finall_tst_ranker_feats = tst_lgb_ranker_feats[['user_id', 'click_article_id']]

for idx, trn_model in enumerate([trn_lgb_ranker_feats, trn_lgb_cls_feats]):
    for feat in [ 'pred_score', 'pred_rank']:
        col_name = feat + '_' + str(idx)
        finall_trn_ranker_feats[col_name] = trn_model[feat]

for idx, tst_model in enumerate([tst_lgb_ranker_feats, tst_lgb_cls_feats]):
    for feat in [ 'pred_score', 'pred_rank']:
        col_name = feat + '_' + str(idx)
        finall_tst_ranker_feats[col_name] = tst_model[feat]

# %%
# 定义一个逻辑回归模型再次拟合交叉验证产生的特征对测试集进行预测
# 这里需要注意的是，在做交叉验证的时候可以构造多一些与输出预测值相关的特征，来丰富这里简单模型的特征
from sklearn.linear_model import LogisticRegression

feat_cols = ['pred_score_0', 'pred_rank_0', 'pred_score_1', 'pred_rank_1']

trn_x = finall_trn_ranker_feats[feat_cols]
trn_y = finall_trn_ranker_feats['label']

tst_x = finall_tst_ranker_feats[feat_cols]

# 定义模型
lr = LogisticRegression()

# 模型训练
lr.fit(trn_x, trn_y)

# 模型预测
finall_tst_ranker_feats['pred_score'] = lr.predict_proba(tst_x)[:, 1]

# %%
# 预测结果重新排序, 及生成提交结果
rank_results = finall_tst_ranker_feats[['user_id', 'click_article_id', 'pred_score']]
submit(rank_results, topk=5, model_name='ensumble_staking')
